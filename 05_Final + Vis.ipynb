# %%
#how many times Winner == F and Winner == '11-14' DONE
#F winner times slower than M winner times? DONE
#more runners -> faster parkrun? DONE
#find the parkrun with most and least runners DONE
#avg median DONE
#no. of runners = seasonality? DONE
#plot winners by and age DONE
#more F or M parkrunners DONE
#fastest time ever DONE
#most wins? DONE
# if winner unknown, I counted 1st known time as winning DONE
# account for course change mean winning and overall times pre / post change - Parkrun id 274 DONE
#avg PB per parkrun DONE

# sprint finish
# M and F attendance by age

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')

# %%
df = pd.read_csv('data/output/keswick_parkrun.csv')
df = df.drop('Unnamed: 0', axis = 1)
df['Winner'][99] = '20:19' ### to repair a glitch
df['Winner (s)'][99] = 20*60+19
# Out:
# /home/kris/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/kris/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df.head(3)
# Out:
#    Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 0         1.0           113.0  18:11          M      20-24    1693.429907
# 1         2.0            66.0  17:03          M      20-24    1687.180328
# 2         3.0            85.0  18:21          M      45-49    1588.500000
#
#    Median (s)  Sub 20     M     F       Winner Name  New PB  Sub 20 (%)  \
# 0      1664.0    11.0  67.0  40.0        Tim RAYNES     0.0        9.73
# 1      1634.0     7.0  28.0  33.0  Richard ANDERSON     8.0       10.61
# 2      1557.5     6.0  48.0  32.0       Steve ANGUS     4.0        7.06
#
#    Winner (s)
# 0      1091.0
# 1      1023.0
# 2      1101.0

# %%
df['Winner Name'].loc[df['Winner M/F'] == 'F']
# Out:
# 23           Rosie SMITH
# 75        Sarah TUNSTALL
# 220    Hayley CARRUTHERS
# 224     Rebecca ROBINSON
# 248       Emily ROBINSON
# Name: Winner Name, dtype: object

# %%
#Avg F winning time is faster than avg M winning time
round(df['Winner (s)'].loc[df['Winner M/F'] == 'F'].mean() - df['Winner (s)'].loc[df['Winner M/F'] == 'M'].mean(), 2)
# Out:
# 32.33

# %%
df['Winner (s)'].loc[df['Winner M/F'] == 'M'].mean()
# Out:
# 1058.4710144927535

# %%
df['Winner Age'].value_counts()
# Out:
# 25-29      76
# 35-39      50
# 20-24      47
# 30-34      30
# Unknown    22
# 40-44      20
# 15-17      18
# 45-49      17
# 18-19      12
# 50-54       8
# 11-14       2
# 55-59       1
# Name: Winner Age, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Winner Age', data=df.sort_values('Winner Age'))
plt.savefig('data/output/winnerage.png')

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(x=df['Parkrun id'], y=df['No. of Runners'].rolling(10).mean(), data=df)
plt.savefig('data/output/attendance.png')

# %%
df[df['No. of Runners'] == df['No. of Runners'].max()]
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 239       240.0           500.0  16:27          M      18-19    1738.925214
#
#      Median (s)  Sub 20      M      F Winner Name  New PB  Sub 20 (%)  \
# 239      1716.5    15.0  220.0  248.0  Luke BOWEN    58.0         3.0
#
#      Winner (s)
# 239       987.0

# %%
df['Winner Name'].value_counts()[df['Winner Name'].value_counts() > 1].head(3)
# Out:
# Sam STEAD    42
# Mark LAMB    31
# Carl BELL    13
# Name: Winner Name, dtype: int64

# %%
df.loc[df['Winner Age'] == '11-14']
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 39         40.0            78.0  18:15          M      11-14    1615.805195
# 166       167.0           239.0  18:02          M      11-14    1676.383260
#
#      Median (s)  Sub 20      M     F   Winner Name  New PB  Sub 20 (%)  \
# 39       1605.0     6.0   42.0  35.0  Nathan SMITH     5.0        7.69
# 166      1610.0    11.0  130.0  97.0   Robin REGAN    31.0        4.60
#
#      Winner (s)
# 39       1095.0
# 166      1082.0

# %%
df.loc[df['Winner Age'] == '55-59']
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 197       198.0           152.0  18:33          M      55-59    1774.183099
#
#      Median (s)  Sub 20     M     F Winner Name  New PB  Sub 20 (%)  \
# 197      1683.0     4.0  76.0  66.0   Greg PENN    25.0        2.63
#
#      Winner (s)
# 197      1113.0

# %%
df.loc[df['Winner Age']== '50-54']
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 16         17.0            86.0  17:10          M      50-54    1687.303797
# 48         49.0            74.0  18:55          M      50-54    1706.845070
# 50         51.0            90.0  18:36          M      50-54    1819.625000
# 67         68.0           133.0  19:04          M      50-54    1751.761538
# 86         87.0           139.0  21:26          M      50-54    1843.674074
# 100       101.0            96.0  19:54          M      50-54    1786.670213
# 147       148.0           142.0  18:20          M      50-54    1691.104478
# 255       256.0           162.0  19:05          M      50-54    1691.463087
#
#      Median (s)  Sub 20     M     F        Winner Name  New PB  Sub 20 (%)  \
# 16       1671.0     8.0  41.0  38.0     Simon ANDERSON    12.0        9.30
# 48       1692.0     3.0  34.0  37.0      Chris KNOWLES    15.0        4.05
# 50       1740.5     4.0  39.0  49.0      Chris KNOWLES    29.0        4.44
# 67       1735.0     4.0  51.0  79.0         Pez BULLEN    34.0        3.01
# 86       1761.0     0.0  62.0  73.0        John CURRAN     4.0        0.00
# 100      1806.0     1.0  49.0  45.0        Darren EDGE     8.0        1.04
# 147      1674.0    10.0  69.0  65.0  Richard PATTINSON    30.0        7.04
# 255      1635.0     1.0  76.0  73.0   Steve BIRKINSHAW    25.0        0.62
#
#      Winner (s)  Avg. Time (minutes)
# 16       1030.0            28.121730
# 48       1135.0            28.447418
# 50       1116.0            30.327083
# 67       1144.0            29.196026
# 86       1286.0            30.727901
# 100      1194.0            29.777837
# 147      1100.0            28.185075
# 255      1145.0            28.191051

# %%
round(df['No. of Runners'].mean())
# Out:
# 149

# %%
round(df['F'].mean())
# Out:
# 65

# %%
round(df['M'].mean())
# Out:
# 74

# %%
len(df[df['F'] - df['M'] > 0])
# Out:
# 51

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df[['M','F']])
plt.savefig('data/output/gender.png')

# %%
df.loc[df['F']/df['No. of Runners']-df['M']/df['No. of Runners'] == 
       (df['F']/df['No. of Runners']-df['M']/df['No. of Runners']).max()]
# Out:
#     Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 67        68.0           133.0  19:04          M      50-54    1751.761538
#
#     Median (s)  Sub 20     M     F Winner Name  New PB  Sub 20 (%)  \
# 67      1735.0     4.0  51.0  79.0  Pez BULLEN    34.0        3.01
#
#     Winner (s)  Avg. Time (minutes)
# 67      1144.0            29.196026

# %%
round(df['New PB'].mean())
# Out:
# 22

# %%
df[df['New PB'] == df['New PB'].max()]
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 239       240.0           500.0  16:27          M      18-19    1738.925214
#
#      Median (s)  Sub 20      M      F Winner Name  New PB  Sub 20 (%)  \
# 239      1716.5    15.0  220.0  248.0  Luke BOWEN    58.0         3.0
#
#      Winner (s)  Avg. Time (minutes)
# 239       987.0            28.982087

# %%
round(df['Sub 20'].mean())
# Out:
# 7

# %%
df['Avg. Time (s)'].mean()
# Out:
# 1709.6435002258831

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize=(12,12));

# %%
df.loc[df['No. of Runners'] == df['No. of Runners'].min()] #smallest parkrun
# Out:
#    Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 5         6.0            54.0  19:05          M      25-29        1828.06
#
#    Median (s)  Sub 20     M     F Winner Name  New PB  Sub 20 (%)  Winner (s)
# 5      1736.5     2.0  22.0  28.0    Tom HOWE     8.0         3.7      1145.0

# %%
df.loc[df['No. of Runners'] == df['No. of Runners'].max()] #biggest parkrun
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 239       240.0           500.0  16:27          M      18-19    1738.925214
#
#      Median (s)  Sub 20      M      F Winner Name  New PB  Sub 20 (%)  \
# 239      1716.5    15.0  220.0  248.0  Luke BOWEN    58.0         3.0
#
#      Winner (s)
# 239       987.0

# %%
df.loc[df['Winner'] == df['Winner'].min()] #fastest kes parkrun time ever
# Out:
#      Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 116       117.0           169.0  15:29          M      18-19    1656.631902
#
#      Median (s)  Sub 20     M     F  Winner Name  New PB  Sub 20 (%)  \
# 116      1616.0    10.0  98.0  65.0  Sam STEVENS    35.0        5.92
#
#      Winner (s)
# 116       929.0

# %%
plt.figure(figsize=(12,6))
df['Avg. Time (minutes)'] = df['Avg. Time (s)']/60
sns.scatterplot(y=df['No. of Runners'], x=df['Avg. Time (minutes)'], color='blue', s=80)                
#plt.savefig('data/output/attendance_speed.png')
    #hue=(df['Avg. Time (s)'].mean()-df['Avg. Time (s)'])**2, legend=False,
                #palette = 'jet_r',
                #)
;
# Out:
# ''

# %%
df.loc[df['Avg. Time (s)'] == df['Avg. Time (s)'].max()]
# Out:
#     Parkrun id  No. of Runners Winner Winner M/F Winner Age  Avg. Time (s)  \
# 88        89.0           104.0  20:26          M      30-34    1902.810526
#
#     Median (s)  Sub 20     M     F Winner Name  New PB  Sub 20 (%)  \
# 88      1843.0     0.0  49.0  46.0  Chris GILL     0.0         0.0
#
#     Winner (s)  Avg. Time (minutes)
# 88      1226.0            31.713509

# %%
round(df['Avg. Time (s)'][df['Parkrun id'] >= 274].mean() - df['Avg. Time (s)'][df['Parkrun id'] < 274].mean())
# Out:
# 21

# %%
round(df['Winner (s)'][df['Parkrun id'] >= 274].mean() - df['Winner (s)'][df['Parkrun id'] < 274].mean())
# Out:
# -22
